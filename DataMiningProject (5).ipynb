# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Motor_Crashed-1.csv")

# %%
df.head()
# Out:
#          Descriptor   Time        Date Day of Week Police Report  \
# 0          Accident   5:35  06/18/2014   Wednesday             Y
# 1   Damage Accident  15:28  11/06/2014    Thursday             Y
# 2   Damage Accident  15:27  03/19/2014   Wednesday             Y
# 3   Damage Accident   4:03  06/23/2014      Monday             Y
# 4   Damage Accident  15:28  09/27/2014    Saturday             Y
#
#    Lighting Conditions Municipality Collision Type Descriptor County Name  \
# 0                 Dawn     NEW YORK                     OTHER    NEW YORK
# 1             Daylight    HENRIETTA               RIGHT ANGLE      MONROE
# 2             Daylight       CICERO                OVERTAKING    ONONDAGA
# 3  Dark-Road Unlighted   COLESVILLE                     OTHER      BROOME
# 4             Daylight       HECTOR                     OTHER    SCHUYLER
#
#       Road Descriptor Weather Conditions Traffic Control Device  \
# ...

# %%
df = df.replace('Unknown', np.nan)

# %%
#df = df.dropna()

# %%
df
# Out:
#                      Descriptor   Time        Date Day of Week Police Report  \
# 0                      Accident   5:35  06/18/2014   Wednesday             Y
# 1               Damage Accident  15:28  11/06/2014    Thursday             Y
# 2               Damage Accident  15:27  03/19/2014   Wednesday             Y
# 3               Damage Accident   4:03  06/23/2014      Monday             Y
# 4               Damage Accident  15:28  09/27/2014    Saturday             Y
# 5               Damage Accident  18:01  02/12/2014   Wednesday             Y
# 6                      Accident  17:15  10/02/2014    Thursday             N
# 7                      Accident   8:28  09/22/2014      Monday             Y
# 8                      Accident  14:25  06/05/2014    Thursday             Y
# 9                      Accident  15:15  03/27/2014    Thursday             Y
# 10              Damage Accident  14:30  12/26/2014      Friday             Y
# ...

# %%
df[' Descriptor'].unique()
# Out:
# array([' Accident', ' Damage Accident', ' Damage & Injury Accident'],
#       dtype=object)

# %%
df[' Descriptor'] = df[' Descriptor'].map({
    ' Accident':0,
    ' Damage Accident':1,
    ' Damage & Injury Accident':2
}.get)

# %%
df = df.replace(':', '', regex=True)

# %%
df = df.replace('/', '', regex=True)

# %%
df['Day of Week'] = df['Day of Week'].map({
    'Monday':1,
    'Tuesday':2,
    'Wednesday':3,
    'Thursday':4,
    'Friday':5,
    'Saturday':6,
    'Sunday':0
}.get)

# %%
df['Police Report'] = df['Police Report'].map({
    'Y':1,
    'N':0
}.get)

# %%
df['Time'] = df['Time'].astype(int)

# %%
df['Date'] = df['Date'].astype(int)

# %%
df
# Out:
#        Descriptor  Time      Date  Day of Week  Police Report  \
# 0               0   535   6182014            3              1
# 1               1  1528  11062014            4              1
# 2               1  1527   3192014            3              1
# 3               1   403   6232014            1              1
# 4               1  1528   9272014            6              1
# 5               1  1801   2122014            3              1
# 6               0  1715  10022014            4              0
# 7               0   828   9222014            1              1
# 8               0  1425   6052014            4              1
# 9               0  1515   3272014            4              1
# 10              1  1430  12262014            5              1
# 11              1  1410  10132014            1              1
# 12              0  1530   5192014            1              1
# 13              2  1635   2142014            5              1
# ...

# %%
df['County Name'].unique()
# Out:
# array(['NEW YORK', 'MONROE', 'ONONDAGA', 'BROOME', 'SCHUYLER', 'CLINTON',
#        'QUEENS', 'KINGS', 'ULSTER', 'SUFFOLK', 'DUTCHESS', 'ERIE',
#        'GREENE', 'CAYUGA', 'BRONX', 'NASSAU', 'ORANGE', 'SENECA',
#        'WESTCHESTER', 'CATTARAUGUS', 'WAYNE', 'TOMPKINS', 'CHAUTAUQUA',
#        'OSWEGO', 'NIAGARA', 'ROCKLAND', 'DELAWARE', 'UNKNOWN', 'SARATOGA',
#        'ONTARIO', 'STEUBEN', 'CHEMUNG', 'LEWIS', 'PUTNAM', 'ALBANY',
#        'ST. LAWRENCE', 'HERKIMER', 'MONTGOMERY', 'ONEIDA', 'MADISON',
#        'JEFFERSON', 'WYOMING', 'LIVINGSTON', 'RICHMOND', 'RENSSELAER',
#        'CHENANGO', 'OTSEGO', 'SULLIVAN', 'SCHOHARIE', 'SCHENECTADY',
#        'ALLEGANY', 'ORLEANS', 'CORTLAND', 'ESSEX', 'COLUMBIA',
#        'WASHINGTON', 'TIOGA', 'HAMILTON', 'GENESEE', 'FULTON', 'FRANKLIN',
#        'WARREN', 'YATES'], dtype=object)

# %%
df['County Name'] = df['County Name'].map({
    'NEW YORK':1, 'MONROE':2, 'ONONDAGA':3, 'BROOME':4, 'SCHUYLER':5, 'CLINTON':6,
       'KINGS':7, 'ULSTER':8, 'QUEENS':9, 'DUTCHESS':10, 'GREENE':11, 'ERIE':12,
       'SUFFOLK':13, 'CAYUGA':14, 'BRONX':15, 'NASSAU':16, 'ORANGE':17, 'SENECA':18,
       'WESTCHESTER':19, 'CATTARAUGUS':20, 'WAYNE':21, 'TOMPKINS':22, 'CHAUTAUQUA':23,
       'OSWEGO':24, 'NIAGARA':25, 'ROCKLAND':26, 'DELAWARE':27, 'SARATOGA':28, 'ONTARIO':29,
       'STEUBEN':30, 'CHEMUNG':31, 'LEWIS':32, 'PUTNAM':33, 'ALBANY':34, 'HERKIMER':35,
       'MONTGOMERY':36, 'ONEIDA':37, 'MADISON':38, 'JEFFERSON':39, 'WYOMING':40,
       'LIVINGSTON':41, 'RICHMOND':42, 'RENSSELAER':43, 'CHENANGO':44, 'OTSEGO':45,
       'SULLIVAN':46, 'SCHOHARIE':47, 'SCHENECTADY':48, 'ALLEGANY':49, 'ORLEANS':50,
       'CORTLAND':51, 'COLUMBIA':52, 'WASHINGTON':53, 'ESSEX':54, 'TIOGA':55,
       'ST. LAWRENCE':56, 'HAMILTON':57, 'GENESEE':58, 'FULTON':59, 'FRANKLIN':60,
       'WARREN':61, 'YATES':0
}.get)

# %%
df['Weather Conditions'].unique()
# Out:
# array(['Clear', 'Rain', 'Cloudy', nan, 'Snow', 'FogSmogSmoke',
#        'SleetHailFreezing Rain', 'Other*'], dtype=object)

# %%
df['Weather Conditions'] = df['Weather Conditions'].map({
    'Clear':1, 'Rain':4, 'Cloudy':2, 'Snow':6, 'Fog/Smog/Smoke':3,
       'Sleet/Hail/Freezing Rain':5, 'Other*':0
}.get)

# %%
df
# Out:
#        Descriptor  Time      Date  Day of Week  Police Report  \
# 0               0   535   6182014            3              1
# 1               1  1528  11062014            4              1
# 2               1  1527   3192014            3              1
# 3               1   403   6232014            1              1
# 4               1  1528   9272014            6              1
# 5               1  1801   2122014            3              1
# 6               0  1715  10022014            4              0
# 7               0   828   9222014            1              1
# 8               0  1425   6052014            4              1
# 9               0  1515   3272014            4              1
# 10              1  1430  12262014            5              1
# 11              1  1410  10132014            1              1
# 12              0  1530   5192014            1              1
# 13              2  1635   2142014            5              1
# ...

# %%
df = df.drop(['Municipality'], axis=1)

# %%
df['Collision Type Descriptor'].unique()
# Out:
# array(['OTHER', 'RIGHT ANGLE', 'OVERTAKING', 'REAR END', nan,
#        'LEFT TURN (3)', 'SIDESWIPE', 'HEAD ON', 'LEFT TURN (0)',
#        'RIGHT TURN (5)', 'RIGHT TURN (6)'], dtype=object)

# %%
df['Collision Type Descriptor'] = df['Collision Type Descriptor'].map({
    'OTHER':0, 'RIGHT ANGLE':1, 'OVERTAKING':2, 'REAR END':3, 'LEFT TURN (3)':4,
       'SIDESWIPE':5, 'HEAD ON':6, 'LEFT TURN (0)':7, 'RIGHT TURN (5)':8,
       'RIGHT TURN (6)':9
}.get)

# %%
df['Lighting Conditions'].unique()
# Out:
# array(['Dawn', 'Daylight', 'Dark-Road Unlighted', nan, 'Dusk',
#        'Dark-Road Lighted'], dtype=object)

# %%
df['Lighting Conditions'] = df['Lighting Conditions'].map({
    'Dawn':1, 'Daylight':0, 'Dark-Road Unlighted':2, 'Dusk':4,
       'Dark-Road Lighted':3
}.get)

# %%
df['Road Descriptor'].unique()
# Out:
# array(['Straight and Level', 'Straight and Grade', nan, 'Curve and Level',
#        'Straight at Hill Crest', 'Curve and Grade', 'Curve at Hill Crest'],
#       dtype=object)

# %%
df['Road Descriptor'] = df['Road Descriptor'].map({
    'Straight and Level':0, 'Straight and Grade':1, 'Curve and Level':2,
       'Curve and Grade':3, 'Straight at Hill Crest':4, 'Curve at Hill Crest':5
}.get)

# %%
df['Traffic Control Device'].unique()
# Out:
# array(['None', nan, 'Traffic Signal', 'Stop Sign', 'Yield Sign',
#        'No Passing Zone', 'Other', 'School Zone', 'Flashing Light',
#        'Construction Work Area', 'Not Applicable', 'Utility Work Area',
#        'RR Crossing Gates', 'Maintenance Work Area', 'OfficerGuard',
#        'Stopped School Bus-Red Lights Flashing', 'PoliceFire Emergency',
#        'RR Crossing Sign'], dtype=object)

# %%
df['Traffic Control Device'] = df['Traffic Control Device'].map({
    'None':15, 'Traffic Signal':1, 'Stop Sign':2, 'No Passing Zone':3, 'Other':4,
       'School Zone':5, 'Yield Sign':6, 'Flashing Light':7,
       'Construction Work Area':8, 'Not Applicable':0, 'RR Crossing Gates':9,
       'Maintenance Work Area':10, 'Officer/Guard':11,
       'Stopped School Bus-Red Lights Flashing':12, 'Police/Fire Emergency':13,
       'RR Crossing Sign':14
}.get)

# %%
df['Road Surface Conditions'].unique()
# Out:
# array(['Dry', 'Wet', nan, 'SnowIce', 'Slush', 'Other', 'Flooded Water',
#        'Muddy'], dtype=object)

# %%
df['Road Surface Conditions'] = df['Road Surface Conditions'].map({
    'Dry':1, 'Wet':2, 'Snow/Ice':6, 'Slush':4, 'Other':0, 'Flooded Water':5,
       'Muddy':3
}.get)

# %%
df['Pedestrian Bicyclist Action'].unique()
# Out:
# array(['Crossing, No Signal or Crosswalk', 'Not Applicable',
#        'Crossing, With Signal', nan, 'Going toFrom Stopped School Bus',
#        'Not in Roadway (Indicate)', 'Crossing, Against Signal',
#        'Other Actions in Roadway',
#        'Crossing, No Signal, Marked Crosswalk',
#        'RidingWalkingSkating Along Highway Against Traffic',
#        'RidingWalkingSkating Along Highway With Traffic',
#        'Working in Roadway',
#        'Getting OnOff Vehicle Other than School Bus',
#        'Emerging from in Front ofBehind Parked Vehicle',
#        'Playing in Roadway'], dtype=object)

# %%
df['Pedestrian Bicyclist Action'] = df['Pedestrian Bicyclist Action'].map({
    'Crossing, No Signal or Crosswalk':1, 'Not Applicable':0,
       'Crossing, With Signal':2, 'Going to/From Stopped School Bus':3,
       'Not in Roadway (Indicate)':4, 'Crossing, Against Signal':5,
       'Other Actions in Roadway':6,
       'Crossing, No Signal, Marked Crosswalk':7,
       'Riding/Walking/Skating Along Highway Against Traffic':8,
       'Riding/Walking/Skating Along Highway With Traffic':9,
       'Working in Roadway':10,
       'Getting On/Off Vehicle Other than School Bus':11,
       'Emerging from in Front of/Behind Parked Vehicle':12,
       'Playing in Roadway':13
}.get)

# %%
df['Event Descriptor'].unique()
# Out:
# array(['Pedestrian, Collision With',
#        'Other Motor Vehicle, Collision With', 'Deer',
#        'Animal, Collision With',
#        'Other Object (Not Fixed)*, Collision With',
#        'Bicyclist, Collision With', 'Other*, Non-Collision',
#        'Guide Rail - Not At End, Collision With Fixed Object',
#        'Tree, Collision With Fixed Object',
#        'Other Fixed Object*, Collision With Fixed Object',
#        'BuildingWall, Collision With Fixed Object',
#        'FireExplosion, Non-Collision',
#        'Barrier, Collision With Fixed Object',
#        'Fence, Collision With Fixed Object', 'Overturned, Non-Collision',
#        'CulverHead Wall, Collision With Fixed Object',
#        'Sign Post, Collision With Fixed Object',
#        'Curbing, Collision With Fixed Object',
#        'Ran Off Roadway Only, Non-Collision',
#        'Snow Embankment, Collision With Fixed Object',
#        'Fire Hydrant, Collision With Fixed Object', nan,
# ...

# %%
df['Event Descriptor'] = df['Event Descriptor'].map({
    'Pedestrian, Collision With':1,
       'Other Motor Vehicle, Collision With':2, 'Deer':3,
       'Animal, Collision With':4,
       'Other Object (Not Fixed)*, Collision With':0,
       'Bicyclist, Collision With':5, 'Other*, Non-Collision':6,
       'Guide Rail - Not At End, Collision With Fixed Object':7,
       'Tree, Collision With Fixed Object':8,
       'Other Fixed Object*, Collision With Fixed Object':9,
       'Building/Wall, Collision With Fixed Object':10,
       'Fire/Explosion, Non-Collision':11,
       'Barrier, Collision With Fixed Object':12,
       'Fence, Collision With Fixed Object':13, 'Overturned, Non-Collision':14,
       'Sign Post, Collision With Fixed Object':15,
       'Curbing, Collision With Fixed Object':16,
       'Snow Embankment, Collision With Fixed Object':17,
       'Ran Off Roadway Only, Non-Collision':18,
       'Fire Hydrant, Collision With Fixed Object':19,
       'Median - Not At End, Collision With Fixed Object':20,
       'Earth Embankment/Rock Cut/Ditch, Collision With Fixed Object':21,
       'Light Support/Utility Pole, Collision With Fixed Object':22,
       'Crash Cushion, Collision With Fixed Object':23,
       'Guide Rail - End, Collision With Fixed Object':24,
       'Other Pedestrian':25,
       'Culver/Head Wall, Collision With Fixed Object':26,
       'Bridge Structure, Collision With Fixed Object':27,
       'Median - End, Collision With Fixed Object':28,
       'In-Line Skater, Collision With':29, 'Submersion, Non-Collision':30
}.get)

# %%
df
# Out:
#        Descriptor  Time      Date  Day of Week  Police Report  \
# 0               0   535   6182014            3              1
# 1               1  1528  11062014            4              1
# 2               1  1527   3192014            3              1
# 3               1   403   6232014            1              1
# 4               1  1528   9272014            6              1
# 5               1  1801   2122014            3              1
# 6               0  1715  10022014            4              0
# 7               0   828   9222014            1              1
# 8               0  1425   6052014            4              1
# 9               0  1515   3272014            4              1
# 10              1  1430  12262014            5              1
# 11              1  1410  10132014            1              1
# 12              0  1530   5192014            1              1
# 13              2  1635   2142014            5              1
# ...

# %%
df.columns
# Out:
# Index([' Descriptor', 'Time', 'Date', 'Day of Week', 'Police Report',
#        'Lighting Conditions', 'Collision Type Descriptor', 'County Name',
#        'Road Descriptor', 'Weather Conditions', 'Traffic Control Device',
#        'Road Surface Conditions', 'Pedestrian Bicyclist Action',
#        'Event Descriptor', 'Number of Vehicles Involved'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
#  Descriptor                       0
# Time                              0
# Date                              0
# Day of Week                       0
# Police Report                     0
# Lighting Conditions             795
# Collision Type Descriptor       905
# County Name                      62
# Road Descriptor                 789
# Weather Conditions              922
# Traffic Control Device          967
# Road Surface Conditions        1728
# Pedestrian Bicyclist Action     213
# Event Descriptor                518
# Number of Vehicles Involved       0
# dtype: int64

# %%
from missingpy import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=10, weights="uniform")
x = imputer.fit_transform(df)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:432: DeprecationWarning: 'warn_on_dtype' is deprecated in version 0.21 and will be removed in 0.23. Don't set `warn_on_dtype` to remove this warning.
#   DeprecationWarning)
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:432: DeprecationWarning: 'warn_on_dtype' is deprecated in version 0.21 and will be removed in 0.23. Don't set `warn_on_dtype` to remove this warning.
#   DeprecationWarning)

# %%
df = pd.DataFrame(x, columns = [' Descriptor', 'Time', 'Date', 'Day of Week', 'Police Report',
       'Lighting Conditions', 'Collision Type Descriptor', 'County Name',
       'Road Descriptor', 'Weather Conditions', 'Traffic Control Device',
       'Road Surface Conditions', 'Pedestrian Bicyclist Action',
       'Event Descriptor', 'Number of Vehicles Involved'])#replaced NaN with KNN

# %%
df
# Out:
#        Descriptor    Time        Date  Day of Week  Police Report  \
# 0             0.0   535.0   6182014.0          3.0            1.0
# 1             1.0  1528.0  11062014.0          4.0            1.0
# 2             1.0  1527.0   3192014.0          3.0            1.0
# 3             1.0   403.0   6232014.0          1.0            1.0
# 4             1.0  1528.0   9272014.0          6.0            1.0
# 5             1.0  1801.0   2122014.0          3.0            1.0
# 6             0.0  1715.0  10022014.0          4.0            0.0
# 7             0.0   828.0   9222014.0          1.0            1.0
# 8             0.0  1425.0   6052014.0          4.0            1.0
# 9             0.0  1515.0   3272014.0          4.0            1.0
# 10            1.0  1430.0  12262014.0          5.0            1.0
# 11            1.0  1410.0  10132014.0          1.0            1.0
# 12            0.0  1530.0   5192014.0          1.0            1.0
# ...

# %%
df.isna().sum()
# Out:
#  Descriptor                    0
# Time                           0
# Date                           0
# Day of Week                    0
# Police Report                  0
# Lighting Conditions            0
# Collision Type Descriptor      0
# County Name                    0
# Road Descriptor                0
# Weather Conditions             0
# Traffic Control Device         0
# Road Surface Conditions        0
# Pedestrian Bicyclist Action    0
# Event Descriptor               0
# Number of Vehicles Involved    0
# dtype: int64

# %%
df['Time'] = df['Time'].apply(lambda x : x / 100)

# %%
df['Time'].head()
# Out:
# 0     5.35
# 1    15.28
# 2    15.27
# 3     4.03
# 4    15.28
# Name: Time, dtype: float64

# %%
df['Date'] = df['Date'].apply(lambda x : x / 1000000)

# %%
df['Date'].head()
# Out:
# 0     6.182014
# 1    11.062014
# 2     3.192014
# 3     6.232014
# 4     9.272014
# Name: Date, dtype: float64

# %%
df.head()
# Out:
#     Descriptor   Time       Date  Day of Week  Police Report  \
# 0          0.0   5.35   6.182014          3.0            1.0
# 1          1.0  15.28  11.062014          4.0            1.0
# 2          1.0  15.27   3.192014          3.0            1.0
# 3          1.0   4.03   6.232014          1.0            1.0
# 4          1.0  15.28   9.272014          6.0            1.0
#
#    Lighting Conditions  Collision Type Descriptor  County Name  \
# 0                  1.0                        0.0          1.0
# 1                  0.0                        1.0          2.0
# 2                  0.0                        2.0          3.0
# 3                  2.0                        0.0          4.0
# 4                  0.0                        0.0          5.0
#
#    Road Descriptor  Weather Conditions  Traffic Control Device  \
# 0              0.0                 1.0                    15.0
# 1              0.0                 4.0                    15.0
# ...

# %%
df.isna().sum()
# Out:
#  Descriptor                    0
# Time                           0
# Date                           0
# Day of Week                    0
# Police Report                  0
# Lighting Conditions            0
# Collision Type Descriptor      0
# County Name                    0
# Road Descriptor                0
# Weather Conditions             0
# Traffic Control Device         0
# Road Surface Conditions        0
# Pedestrian Bicyclist Action    0
# Event Descriptor               0
# Number of Vehicles Involved    0
# dtype: int64
